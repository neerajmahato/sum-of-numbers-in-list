# %%
#  Write a Python function to sum all the numbers in a list.

def sum_list(items):
    sum_numbers = 0
    for i in items:
        sum_numbers += i
    return sum_numbers
print(sum_list([8, 2, 3, 0, 7]))
# Out:
# 20
